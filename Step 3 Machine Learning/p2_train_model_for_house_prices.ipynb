# %%
import pandas as pd
import plotly.express as px

# %%
house_prices = pd.read_csv('../data/house_size_price.csv')
house_prices.head()
# Out:
#    size   price
# 0   901  301900
# 1  3983  851200
# 2  3446  768200
# 3  2475  542200
# 4  2449  531300

# %%
px.scatter(x=house_prices['size'], y=house_prices['price'], title='House Price vs Size', labels={'x': 'Size (sq ft)', 'y': 'Price ($)'})

# %% [markdown]
# # when we have data size and price
# # we train a machine learning model with size and price
# # after training if we give it size it will tell us price

# %%
# train a model that can take size and give me price
